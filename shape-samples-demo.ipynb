# %% [markdown]
# ### Uncomment this when Running in Colab

# %%
#!pip install --quiet phiflow==2.2.2
#import os
#if not os.path.isdir('eigenfluid-control'):
#  print("Cloning eigenfluid-control repo, this can take a moment")
#  os.system("git clone https://github.com/bobarna/eigenfluid-control")
#import sys; sys.path.append('eigenfluid-control')

# %% [markdown]
# ## Imports & Initialization

# %%
from phi.torch.flow import *
import matplotlib.pyplot as plt

#from src.eigenfluid import Eigenfluid
from src.shapes import *

# Helper functions for visualization
from src.visu import *

import time

# %% [markdown]
# # Demo for Sampling Points on Shapes

# %%
DOMAIN = Box(x=math.PI, y=math.PI)

c = Circle(pos=(1.5, 1.5), size=1)
s = Square(pos=(0.3, 2.0))
t = Triangle(pos=(0.5, 0.5))


O = 30
U = 30

p_0, p_t = get_points_for_shapes(c, t, O=O, U=U)
p_0 = math.concat([p_0, c.create_points(c.get_trivial_points())], instance('i'))
p_t = math.concat([p_t, t.create_points(t.get_trivial_points())], instance('i'))

p_s, _ = get_points_for_shapes(s,s, O, U)

vis.plot(vis.overlay(
    PointCloud(p_0, bounds=DOMAIN),
    PointCloud(p_t, bounds=DOMAIN),
    #PointCloud(p_s, bounds=DOMAIN),
    c.get_smoke(x=200, y=200) + t.get_smoke(x=200, y=200) #+ s.get_smoke(),
), size=(5,5), show_color_bar=True)

# %%
vis.plot({
    "Triangle": t.get_smoke(x=200, y=200),
    "Circle": c.get_smoke(x=200, y=200),
    "Square": s.get_smoke(x=200, y=200)
}, size=(10,5), show_color_bar=False)

# %%
# sampling overlapping + unique points on both shapes

sampler_union = ShapeSampler(t, c, N=10, h1=2, h2=7)
sampler_t = ShapeSampler(t, N=20, h1=3, h2=11)
sampler_c = ShapeSampler(c, N=20, h1=3, h2=11)

# TODO: new PhiFlow version broke older PointCloud-wise color setting.
# I made it work in the other notebooks, but couldn't figure out how to 
# plot tensors of varying size (?), which currently throws NotImplementedError

p_vis = stack([
    t.create_points(t.get_trivial_points()),
    t.create_points(sampler_t.p),
    t.create_points(sampler_union.p),
    c.create_points(c.get_trivial_points()),
    c.create_points(sampler_c.p),
    c.create_points(sampler_union.p)
], instance("points"))

COLOR = wrap(
    ["red", "green", "blue", "red", "green", "blue"],
    instance("points")
)

plot(
    PointCloud(p_vis, bounds=DOMAIN),
    size=(5,5),
    color=COLOR
)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In [51], line 21
#       7 p_vis = stack([
#       8     t.create_points(t.get_trivial_points()),
#       9     t.create_points(sampler_t.p),
#    (...)
#      13     c.create_points(sampler_union.p)
#      14 ], instance("points"))
#      16 COLOR = wrap(
#      17     ["red", "green", "blue", "red", "green", "blue"],
#      18     instance("points")
#      19 )
# ---> 21 plot(
#      22     PointCloud(p_vis, bounds=DOMAIN),
#      23     size=(5,5),
#      24     color=COLOR
#      25 )
#
# File ~/codes/phiflow/phi/vis/_vis.py:334, in plot(lib, row_dims, col_dims, animate, overlay, title, size, same_scale, log_dims, show_color_bar, color, frame_time, repeat, *fields)
#     332         max_val = max([float(abs(f.values).finite_max) for l in positioning.values() for f in l])
#     333     else:
# --> 334         min_val = min([float(f.values.finite_min) for l in positioning.values() for f in l])
#     335         max_val = max([float(f.values.finite_max) for l in positioning.values() for f in l])
#     336 else:
#
# File ~/codes/phiflow/phi/vis/_vis.py:334, in <listcomp>(.0)
#     332         max_val = max([float(abs(f.values).finite_max) for l in positioning.values() for f in l])
#     333     else:
# --> 334         min_val = min([float(f.values.finite_min) for l in positioning.values() for f in l])
#     335         max_val = max([float(f.values.finite_max) for l in positioning.values() for f in l])
#     336 else:
#
# File ~/codes/phiflow/phi/math/_tensors.py:295, in Tensor.finite_min(self)
#     293 """ Minimum finite value of this `Tensor` as a native scalar. """
#     294 from ._ops import finite_min
# --> 295 return finite_min(self, dim=self.shape).native()
#
# File ~/codes/phiflow/phi/math/_ops.py:1352, in finite_min(value, dim, default)
#    1332 def finite_min(value, dim: DimFilter = non_batch, default: complex or float = float('NaN')):
#    1333     """
#    1334     Finds the minimum along `dim` ignoring all non-finite values.
#    1335
#    (...)
#    1350         `Tensor` without the reduced dimensions.
#    1351     """
# -> 1352     value_inf = where(is_finite(value), value, float('inf'))
#    1353     result_inf = min_(value_inf, dim)
#    1354     return where(is_finite(result_inf), result_inf, default)
#
# File ~/codes/phiflow/phi/math/_ops.py:975, in where(condition, value_true, value_false)
#     972     result = choose_backend(c, vt, vf).where(c, vt, vf)
#     973     return NativeTensor(result, shape)
# --> 975 return broadcast_op(inner_where, [condition, value_true, value_false])
#
# File ~/codes/phiflow/phi/math/_ops.py:917, in broadcast_op(operation, tensors, iter_dims, no_return)
#     915             iter_dims.add(tensor._stack_dim.name)
#     916 if len(iter_dims) == 0:
# --> 917     return operation(*tensors)
#     918 else:
#     919     if isinstance(iter_dims, Shape):
#
# File ~/codes/phiflow/phi/math/_ops.py:971, in where.<locals>.inner_where(c, vt, vf)
#     969 if vt._is_tracer or vf._is_tracer or c._is_tracer:
#     970     return c * vt + (1 - c) * vf  # ToDo this does not take NaN into account
# --> 971 shape, (c, vt, vf) = broadcastable_native_tensors(c, vt, vf)
#     972 result = choose_backend(c, vt, vf).where(c, vt, vf)
#     973 return NativeTensor(result, shape)
#
# File ~/codes/phiflow/phi/math/_tensors.py:1859, in broadcastable_native_tensors(*tensors)
#    1857     tensors = [dense(t) for t in tensors]
#    1858 broadcast_shape = merge_shapes(*[t.shape for t in tensors])
# -> 1859 natives = [t.native(order=broadcast_shape.names) if t.rank > 0 else t.native() for t in tensors]
#    1860 return broadcast_shape, natives
#
# File ~/codes/phiflow/phi/math/_tensors.py:1859, in <listcomp>(.0)
#    1857     tensors = [dense(t) for t in tensors]
#    1858 broadcast_shape = merge_shapes(*[t.shape for t in tensors])
# -> 1859 natives = [t.native(order=broadcast_shape.names) if t.rank > 0 else t.native() for t in tensors]
#    1860 return broadcast_shape, natives
#
# File ~/codes/phiflow/phi/math/_tensors.py:1285, in CollapsedTensor.native(self, order)
#    1283 order = parse_dim_order(order, check_rank=self.rank)
#    1284 if order is None or tuple(order) == self.shape.names:
# -> 1285     return self._cache().native(order)
#    1286 else:
#    1287     native = self._inner.native(order=order)
#
# File ~/codes/phiflow/phi/math/_tensors.py:1267, in CollapsedTensor._cache(self)
#    1265         self._inner = None
#    1266     else:
# -> 1267         raise NotImplementedError()
#    1268 return self._cached
#
# NotImplementedError:
