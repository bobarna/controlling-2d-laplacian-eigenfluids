# %% [markdown]
# # Eigenfluid Control Force Optimization
#
# In this notebook, we optimize for a control force vector $\textbf{f} \in \mathbb{R}^{t \times N}$, where $t$ is the number of timesteps simulated, and $N$ is the number of basis coefficients in the Eigenfluid simulation.
#
# $\text{Loss}(\textbf{p}_0, \textbf{p}_t, \textbf{f}, \textbf{w}_0) =
# \left|\left|
#     (\mathcal{P}\circ\mathcal{F}_f)^t(\textbf{p}_0, \textbf{w}_0) - \textbf{p}_t
# \right|\right|_2^2$
#
# TIME_STEPS is fixed (=16)

# %% [markdown]
# ### Uncomment this when Running in Colab

# %%
#!pip install --quiet phiflow==2.2.2
#import os
#if not os.path.isdir('eigenfluid-control'):
#  print("Cloning eigenfluid-control repo, this can take a moment")
#  os.system("git clone https://github.com/bobarna/eigenfluid-control")
#import sys; sys.path.append('eigenfluid-control')

# %% [markdown]
# ## Imports & Initialization

# %%
from phi.torch.flow import *
import matplotlib.pyplot as plt

from src.eigenfluid import Eigenfluid
from src.shapes import *

# Helper functions for visualization
from src.visu import *

import time

# %%
# Number of basis fields
N = 4**2
# Domain sizes
DOMAIN = Box(x=math.PI, y=math.PI)
SAMPLING_SIZE = 32

start_time = time.time()
eigenfluid = Eigenfluid(N, DOMAIN, SAMPLING_SIZE)
end_time = time.time()
print("Eigenfluid initialized in {} seconds".format(end_time-start_time))
# Out:
# Eigenfluid initialized in 10.657975912094116 seconds

# %% [markdown]
# # Initialize Start and Target Points

# %%
shape_0 = Square(pos=(0.5, 0.5))
shape_target = Triangle(pos=(2, 2))

# Get O overlapping, and U non-necessarily overlapping ('unique') sample points
O = 20
U = 25

p_0, p_t = get_points_for_shapes(shape_0, shape_target, O, U)

p_0 = concat([p_0, shape_0.create_points(shape_0.get_trivial_points())], instance('i'))
p_t = concat([p_t, shape_target.create_points(shape_target.get_trivial_points())], instance('i'))

# get only trivial points
p_0 = shape_0.create_points(shape_0.get_trivial_points())
p_t = shape_target.create_points(shape_target.get_trivial_points())

p_vis = stack([p_0, p_t], instance("points"))

COLOR = wrap(['blue', 'red'], instance(p_vis)["points"])

plot({"Blue: start\nRed: target": PointCloud(p_vis, bounds=DOMAIN)},
     size=(3,3), color=COLOR
)

# %% [markdown]
# # Loss Function

# %%
STEPS = 16
DT    = 0.2
VISCOSITY = 0.0

# Initialize the force vector to zero
f_optim = math.zeros(eigenfluid.w.shape & batch(time=STEPS-1))

def loss_function(f_optim, w, p, p_target):
    trajectory_p = [p]
    for t in range(STEPS-1):
        # Step velocity
        w = eigenfluid.step_w_euler(w, DT, viscosity=VISCOSITY)
        # Add control forces
        w += f_optim.time[t]
        # Get velocities at new positions
        v_phi = eigenfluid.phi_template(w, eigenfluid.N, eigenfluid.basis_fields)
        p_velocities = v_phi(p)
        # Midpoint
        p_velocities = v_phi(p + p_velocities*DT/2)
        # Euler step for points
        p += p_velocities * DT
        trajectory_p.append(p)
    # Normalizing by the number of sample points
    loss = field.l2_loss(p - p_target) / p.i.size
    return (loss, trajectory_p)

gradient_function = math.gradient(loss_function)

# %%
w_init = eigenfluid.w

# first gradient
(loss, trajectory_p), grad = gradient_function(f_optim, w_init, p_0, p_t)
print("Initial Loss: {}".format(loss))
# Out:
# Initial Loss: 2.1971688

# %%
LR = 10**-2 / 2

grads = [0]

for optim_step in range(101):
    (loss, trajectory_p), grad = gradient_function(f_optim, w_init, p_0, p_t)
    if optim_step%3 == 0 or optim_step < 5:
        print("Optimization step %d, loss: %f" % (optim_step, loss))
    if optim_step == 41:
        LR /= 2
        print("LR = {}".format(LR))
        
    grads.append( grad[0] )

    # optionally with momentum
    f_optim = f_optim - LR * grads[-1]
# Out:
# Optimization step 0, loss: 2.197169
# Optimization step 1, loss: 2.098467
# Optimization step 2, loss: 1.997106
# Optimization step 3, loss: 1.893355
# Optimization step 4, loss: 1.787819
# Optimization step 6, loss: 1.575110
# Optimization step 9, loss: 1.274978
# Optimization step 12, loss: 1.023906
# Optimization step 15, loss: 0.803329
# Optimization step 18, loss: 0.624990
# Optimization step 21, loss: 0.513296
# Optimization step 24, loss: 0.437815
# Optimization step 27, loss: 0.380220
# Optimization step 30, loss: 0.333772
# Optimization step 33, loss: 0.295591
# Optimization step 36, loss: 0.263955
# Optimization step 39, loss: 0.237557
# LR = 0.0025
# Optimization step 42, loss: 0.218813
# Optimization step 45, loss: 0.208793
# Optimization step 48, loss: 0.199530
# Optimization step 51, loss: 0.190947
# Optimization step 54, loss: 0.182975
# Optimization step 57, loss: 0.175555
# Optimization step 60, loss: 0.168632
# Optimization step 63, loss: 0.162161
# Optimization step 66, loss: 0.156102
# Optimization step 69, loss: 0.150417
# Optimization step 72, loss: 0.145077
# Optimization step 75, loss: 0.140053
# Optimization step 78, loss: 0.135320
# Optimization step 81, loss: 0.130856
# Optimization step 84, loss: 0.126642
# Optimization step 87, loss: 0.122660
# Optimization step 90, loss: 0.118893
# Optimization step 93, loss: 0.115327
# Optimization step 96, loss: 0.111949
# Optimization step 99, loss: 0.108746

# %%
trajectory_p = math.stack(trajectory_p, batch('time'))
target_time = math.stack([p_t]*STEPS, batch('time'))

# %%
# Generate smoke trajectory
smoke_traj = [shape_0.get_smoke()]
w = w_init

for t in range(STEPS-1):
    # Step velocity
    w = eigenfluid.step_w_euler(w, DT, viscosity=VISCOSITY)
    # Add control forces
    w += f_optim.time[t]
    
    velocity = eigenfluid.reconstruct_velocity(w)
    smoke = advect.mac_cormack(smoke_traj[-1], velocity, dt=DT)
    smoke_traj.append(smoke)
smoke_traj = math.stack(smoke_traj, batch('time'))

# %%
p_vis = stack([trajectory_p, target_time], instance("points"))
vis.plot({ 
    "N={}, t={}, {}x{}\nO={}, U={}, T=5".format(N, STEPS, SAMPLING_SIZE, SAMPLING_SIZE, 0, 0): vis.overlay(
        smoke_traj,
        p_vis
    )},
    animate='time',
    same_scale=False,
    size=(6,5),
    show_color_bar = False,
    #frame_time=150
    color=COLOR
)
# Out:
# <video width="600" height="500" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
import pylab

target_smoke = shape_target.get_smoke()

pylab.subplots(1, 9, sharey='row', sharex='col', figsize=(12, 7))
pylab.tight_layout(w_pad=0)
for t in range(9):
    pylab.subplot(1, 9, (t+1))
    if t == 8:
        pylab.title('target\nt=15')
        pylab.imshow(target_smoke.values - smoke_traj.time[-1].values, origin='upper')
    else:
        pylab.title('t={}'.format(t*2))
        pylab.imshow(smoke_traj.time[(t*2)].values, origin='upper')
